# %% [markdown]
# ![](tec.png)
#
#
#
# ## Análisis de Datos Masivos
# ## SpeedTest
# ## Nombre del docente
# ### José Gabriel Rodriguez Rivas
# ## Nombre del alumno
# ### Najib Alejandro Loera Rodriguez

# %%
# Importar librerias
import datetime
import csv
import subprocess

# %% [markdown]
# ### Paso 2: Genere las marcas de hora mediante el paquete datetime.

# %%
# Code cell 3
date_time = datetime.datetime.now()
print(date_time, type(date_time))
# Out:
# 2020-07-23 13:57:31.950927 <class 'datetime.datetime'>

# %%
# Code cell 4
date_time.strftime('%a, %d %b %Y %H:%M:%S')
# Out:
# 'Thu, 23 Jul 2020 13:57:31'

# %% [markdown]
# ### Paso 3: Ejecute el proceso y recopile la salida con Python.

# %%
# Code cell 6
# This string contains the command line to interface with speedtest.net
speedtest_cmd = "speedtest-cli --simple"
# Execute the process
process = subprocess.Popen(speedtest_cmd.split(), stdout=subprocess.PIPE)
# Collect the command output
process_output = process.communicate()[0]

# %%
# Code cell 7
print(process_output, type(process_output))
# Out:
# b'Ping: 95.047 ms\r\nDownload: 1.07 Mbit/s\r\nUpload: 0.42 Mbit/s\r\n' <class 'bytes'>

# %%
# Code cell 8
# Store the time at which the speedtest was executed
date_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
process_output = process_output.split()
process_output.append(date_time)
print(process_output, type(process_output))
# Out:
# [b'Ping:', b'95.047', b'ms', b'Download:', b'1.07', b'Mbit/s', b'Upload:', b'0.42', b'Mbit/s', '2020-07-23 13:58:15'] <class 'list'>

# %%
# Code cell 9
# function to excute the speed test
def speedtest():
    # We need to store the time at which the speedtest was executed
    date_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    # This is a string that contains what we would write on the command line 
    #to interface with speedtest.net
    speedtest_cmd = "speedtest-cli --simple"
    # We now execute the process: 
    process = subprocess.Popen(speedtest_cmd.split(), stdout=subprocess.PIPE)
    process_output = process.communicate()[0]
    process_output = process_output.split()
    # and we add the date and time 
    process_output.append(date_time)
    return process_output

# %% [markdown]
# ### ¿Qué devuelve la función speedtest()? ¿Cuál es el código para ver resultados de la función speedtest()?

# %%
speedtest()
# Out:
# [b'Ping:',
#  b'50.694',
#  b'ms',
#  b'Download:',
#  b'1.50',
#  b'Mbit/s',
#  b'Upload:',
#  b'1.20',
#  b'Mbit/s',
#  '2020-07-23 13:58:15']

# %% [markdown]
# ### Paso 4: Guarde la salida de la función speedtest().

# %%
# Code cell 11
with open("test1.txt",'w') as f:
    f.write('test_msg')

# %%
# Code cell 13
with open("test.txt",'r') as f:
    str = f.read()
print(str)
# Out:
# test_msg

# %%
def save_to_csv(data, filename):
    try:
        # If the file exists, append a new line to it, with the 
        #results of the current experiment
        with open(filename + '.csv', 'a') as f:
            # Create a csv writer object 
            wr = csv.writer(f)
            # Save (write) to file
            wr.writerow(data)
    except:
        # If it does not exist, create the file first
        with open(filename + '.csv', 'w') as f:
             # Create a csv writer object 
            wr = csv.writer(f)
            # Save (write) to file
            wr.writerow(data)

# %% [markdown]
# ###  Paso 5: Verifique los datos recolectados.

# %%
# Code cell 15
def print_from_csv(filename): 
    with open(filename + '.csv', 'r') as f:
        re = csv.reader(f)
        for row in re:
            print(', '.join(row))

# %% [markdown]
# ### Paso 6: Ejecute varias veces Speedtest y guarde los datos.

# %%
# Code cell 16
for i in range(5):
    # Measure internet speed (speedtest_output) using the speedtest() created earlier
    speedtest_output = speedtest()
    # Print the test number
    print('Test number {}'.format(i))
    # Print the result (The needed variable is speedtest_output)
    # ADD CODE HERE for printing the results
    print(speedtest_output)
    save_to_csv(speedtest_output, 'rpi_test')
# Out:
# Test number 0
# [b'Ping:', b'50.309', b'ms', b'Download:', b'0.65', b'Mbit/s', b'Upload:', b'0.92', b'Mbit/s', '2020-07-23 13:58:52']
# Test number 1
# [b'Ping:', b'41.416', b'ms', b'Download:', b'4.45', b'Mbit/s', b'Upload:', b'1.34', b'Mbit/s', '2020-07-23 13:59:30']
# Test number 2
# [b'Ping:', b'52.078', b'ms', b'Download:', b'1.04', b'Mbit/s', b'Upload:', b'0.91', b'Mbit/s', '2020-07-23 14:00:00']
# Test number 3
# [b'Ping:', b'53.035', b'ms', b'Download:', b'0.93', b'Mbit/s', b'Upload:', b'1.04', b'Mbit/s', '2020-07-23 14:00:39']
# Test number 4
# [b'Ping:', b'49.436', b'ms', b'Download:', b'1.27', b'Mbit/s', b'Upload:', b'0.61', b'Mbit/s', '2020-07-23 14:01:12']

# %%
# Code cell 17
print_from_csv('rpi_test')
# Out:
# b'Ping:', b'91.442', b'ms', b'Download:', b'9.60', b'Mbit/s', b'Upload:', b'9.85', b'Mbit/s', 2020-07-22 08:40:59
#
# b'Ping:', b'108.099', b'ms', b'Download:', b'9.62', b'Mbit/s', b'Upload:', b'8.88', b'Mbit/s', 2020-07-22 08:41:27
#
# b'Ping:', b'106.701', b'ms', b'Download:', b'10.11', b'Mbit/s', b'Upload:', b'8.01', b'Mbit/s', 2020-07-22 08:41:56
#
# b'Ping:', b'98.689', b'ms', b'Download:', b'9.93', b'Mbit/s', b'Upload:', b'10.73', b'Mbit/s', 2020-07-22 08:42:25
#
# b'Ping:', b'96.196', b'ms', b'Download:', b'10.53', b'Mbit/s', b'Upload:', b'9.68', b'Mbit/s', 2020-07-22 08:42:53
#
# b'Ping:', b'101.228', b'ms', b'Download:', b'10.62', b'Mbit/s', b'Upload:', b'10.42', b'Mbit/s', 2020-07-22 08:43:22
#
# b'Ping:', b'100.064', b'ms', b'Download:', b'10.43', b'Mbit/s', b'Upload:', b'10.03', b'Mbit/s', 2020-07-22 08:43:50
#
# b'Ping:', b'106.372', b'ms', b'Download:', b'10.21', b'Mbit/s', b'Upload:', b'9.97', b'Mbit/s', 2020-07-22 08:44:18
#
# b'Ping:', b'116.559', b'ms', b'Download:', b'9.23', b'Mbit/s', b'Upload:', b'10.58', b'Mbit/s', 2020-07-22 08:44:49
#
# b'Ping:', b'101.823', b'ms', b'Download:', b'10.20', b'Mbit/s', b'Upload:', b'10.38', b'Mbit/s', 2020-07-22 08:45:19
#
# b'Ping:', b'103.801', b'ms', b'Download:', b'10.29', b'Mbit/s', b'Upload:', b'10.30', b'Mbit/s', 2020-07-22 09:02:27
#
# b'Ping:', b'99.346', b'ms', b'Download:', b'10.52', b'Mbit/s', b'Upload:', b'8.76', b'Mbit/s', 2020-07-22 09:02:55
#
# b'Ping:', b'101.966', b'ms', b'Download:', b'10.58', b'Mbit/s', b'Upload:', b'10.85', b'Mbit/s', 2020-07-22 09:03:23
#
# b'Ping:', b'102.687', b'ms', b'Download:', b'10.55', b'Mbit/s', b'Upload:', b'10.15', b'Mbit/s', 2020-07-22 09:03:52
#
# b'Ping:', b'98.644', b'ms', b'Download:', b'9.80', b'Mbit/s', b'Upload:', b'8.35', b'Mbit/s', 2020-07-22 09:04:19
#
# b'Ping:', b'50.309', b'ms', b'Download:', b'0.65', b'Mbit/s', b'Upload:', b'0.92', b'Mbit/s', 2020-07-23 13:58:52
#
# b'Ping:', b'41.416', b'ms', b'Download:', b'4.45', b'Mbit/s', b'Upload:', b'1.34', b'Mbit/s', 2020-07-23 13:59:30
#
# b'Ping:', b'52.078', b'ms', b'Download:', b'1.04', b'Mbit/s', b'Upload:', b'0.91', b'Mbit/s', 2020-07-23 14:00:00
#
# b'Ping:', b'53.035', b'ms', b'Download:', b'0.93', b'Mbit/s', b'Upload:', b'1.04', b'Mbit/s', 2020-07-23 14:00:39
#
# b'Ping:', b'49.436', b'ms', b'Download:', b'1.27', b'Mbit/s', b'Upload:', b'0.61', b'Mbit/s', 2020-07-23 14:01:12

# %% [markdown]
# ###  ¿Cómo cambiaría el código si quisiera ejecutar el código 100 veces?
#
# ### Respuesta: Cambiando en el ciclo for in range(5) el 5 por 100

# %% [markdown]
# ## ***Parte DOS Manipule los datos***

# %%
# importar librerias
import datetime
import csv
import pandas as pd
import numpy as np

# %%
# Code cell 20
data_file = 'rpi_data.csv'

# %% [markdown]
# ### Paso 2: Cargue el archivo csv en un objeto del marco de datos mediante pandas.

# %%
# Code cell 22
# Le agregamos los encabezados al frame
column_names = [ 'Type A', 'Measure A', 'Units A',
                 'Type B', 'Measure B', 'Units B',
                 'Type C', 'Measure C', 'Units C', 
                 'Datetime']

# %%
# Code cell 23
#El csv lo estamos convirtiendo a un data frame
with open(data_file, 'r') as f:
    df_redundant = pd.read_csv(f, names = column_names)

# %%
df_redundant.head()
# Out:
#   Type A  Measure A Units A     Type B  Measure B Units B   Type C  Measure C  \
# 0  Ping:     26.992      ms  Download:      91.80  Mbit/s  Upload:      14.31
# 1  Ping:     24.532      ms  Download:      88.19  Mbit/s  Upload:      14.12
# 2  Ping:     20.225      ms  Download:      59.86  Mbit/s  Upload:      14.11
# 3  Ping:     19.332      ms  Download:      91.81  Mbit/s  Upload:      14.22
# 4  Ping:     22.494      ms  Download:      92.05  Mbit/s  Upload:      14.08
#
#   Units C             Datetime
# 0  Mbit/s  2016-11-24 13:36:25
# 1  Mbit/s  2016-11-24 13:36:55
# 2  Mbit/s  2016-11-24 13:37:25
# 3  Mbit/s  2016-11-24 13:37:57
# 4  Mbit/s  2016-11-24 13:38:27

# %% [markdown]
# ### ¿Cuál es el código para leer las primeras 20 líneas del archivo csv?
# ### Respuesta:

# %%
df_redundant.head(20)
# Out:
#    Type A  Measure A Units A     Type B  Measure B Units B   Type C  \
# 0   Ping:     26.992      ms  Download:      91.80  Mbit/s  Upload:
# 1   Ping:     24.532      ms  Download:      88.19  Mbit/s  Upload:
# 2   Ping:     20.225      ms  Download:      59.86  Mbit/s  Upload:
# 3   Ping:     19.332      ms  Download:      91.81  Mbit/s  Upload:
# 4   Ping:     22.494      ms  Download:      92.05  Mbit/s  Upload:
# 5   Ping:     17.586      ms  Download:      91.88  Mbit/s  Upload:
# 6   Ping:     21.835      ms  Download:      92.18  Mbit/s  Upload:
# 7   Ping:     20.464      ms  Download:      92.05  Mbit/s  Upload:
# 8   Ping:     19.293      ms  Download:      90.79  Mbit/s  Upload:
# 9   Ping:     20.354      ms  Download:      92.64  Mbit/s  Upload:
# 10  Ping:     19.010      ms  Download:      91.86  Mbit/s  Upload:
# 11  Ping:     18.092      ms  Download:      92.24  Mbit/s  Upload:
# 12  Ping:     18.137      ms  Download:      91.64  Mbit/s  Upload:
# 13  Ping:     18.344      ms  Download:      92.85  Mbit/s  Upload:
# 14  Ping:     23.328      ms  Download:      92.21  Mbit/s  Upload:
# 15  Ping:     17.908      ms  Download:      92.24  Mbit/s  Upload:
# 16  Ping:     19.291      ms  Download:      92.41  Mbit/s  Upload:
# 17  Ping:     20.117      ms  Download:      90.39  Mbit/s  Upload:
# 18  Ping:     19.579      ms  Download:      92.55  Mbit/s  Upload:
# 19  Ping:     16.364      ms  Download:      78.51  Mbit/s  Upload:
#
#     Measure C Units C             Datetime
# 0       14.31  Mbit/s  2016-11-24 13:36:25
# 1       14.12  Mbit/s  2016-11-24 13:36:55
# 2       14.11  Mbit/s  2016-11-24 13:37:25
# 3       14.22  Mbit/s  2016-11-24 13:37:57
# 4       14.08  Mbit/s  2016-11-24 13:38:27
# 5       14.18  Mbit/s  2016-11-24 13:39:01
# 6       14.07  Mbit/s  2016-11-24 13:39:30
# 7       14.13  Mbit/s  2016-11-24 13:40:00
# 8       14.14  Mbit/s  2016-11-24 13:40:30
# 9       14.07  Mbit/s  2016-11-24 13:41:00
# 10      14.38  Mbit/s  2016-11-24 13:41:30
# 11      14.23  Mbit/s  2016-11-24 13:42:00
# 12      14.32  Mbit/s  2016-11-24 13:42:30
# 13      14.20  Mbit/s  2016-11-24 13:43:00
# 14      14.20  Mbit/s  2016-11-24 13:43:29
# 15      11.36  Mbit/s  2016-11-24 13:43:59
# 16      14.03  Mbit/s  2016-11-24 13:44:31
# 17      14.17  Mbit/s  2016-11-24 13:45:01
# 18      14.06  Mbit/s  2016-11-24 13:45:32
# 19      13.71  Mbit/s  2016-11-24 13:46:02

# %% [markdown]
# ### Paso 3: Cree una representación concisa.

# %%
# Code cell 25
df_compact = df_redundant.copy()

# %%
# Code cell 26
df_compact.rename(columns={'Measure A':'Ping (ms)', 
                           'Measure B': 'Download (Mbit/s)',
                           'Measure C': 'Upload (Mbit/s)'}, inplace=True)
df_compact.head(3)
# Out:
#   Type A  Ping (ms) Units A     Type B  Download (Mbit/s) Units B   Type C  \
# 0  Ping:     26.992      ms  Download:              91.80  Mbit/s  Upload:
# 1  Ping:     24.532      ms  Download:              88.19  Mbit/s  Upload:
# 2  Ping:     20.225      ms  Download:              59.86  Mbit/s  Upload:
#
#    Upload (Mbit/s) Units C             Datetime
# 0            14.31  Mbit/s  2016-11-24 13:36:25
# 1            14.12  Mbit/s  2016-11-24 13:36:55
# 2            14.11  Mbit/s  2016-11-24 13:37:25

# %%
# Code cell 27
df_compact.drop(['Type A', 'Type B', 'Type C',
         'Units A', 'Units B', 'Units C'], axis=1, inplace=True)
df_compact.head()
# Out:
#    Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)             Datetime
# 0     26.992              91.80            14.31  2016-11-24 13:36:25
# 1     24.532              88.19            14.12  2016-11-24 13:36:55
# 2     20.225              59.86            14.11  2016-11-24 13:37:25
# 3     19.332              91.81            14.22  2016-11-24 13:37:57
# 4     22.494              92.05            14.08  2016-11-24 13:38:27

# %% [markdown]
# ### Paso 4: Separe los datos en dos columnas

# %%
# Code cell 28
df_compact['Date'] = df_compact['Datetime'].apply(lambda dt_str: pd.to_datetime(dt_str).date())

# %%
# Code cell 28
df_compact['Time'] = df_compact['Datetime'].apply(lambda dt_str: pd.to_datetime(dt_str).time())

# %%
# Code cell 32
print(df_compact['Date'][0], type(df_compact['Date'][0]) )
print(df_compact['Time'][0], type(df_compact['Time'][0]) )
# Out:
# 2016-11-24 <class 'datetime.date'>
# 13:36:25 <class 'datetime.time'>

# %%
# Code cell 30
df_compact.drop(['Datetime'], axis=1, inplace=True)
df_compact.head()
# Out:
#    Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)        Date      Time
# 0     26.992              91.80            14.31  2016-11-24  13:36:25
# 1     24.532              88.19            14.12  2016-11-24  13:36:55
# 2     20.225              59.86            14.11  2016-11-24  13:37:25
# 3     19.332              91.81            14.22  2016-11-24  13:37:57
# 4     22.494              92.05            14.08  2016-11-24  13:38:27

# %%
# Code cell 33
df_compact.to_csv('data_compact.csv')

# %%
df_compact
# Out:
#      Ping (ms)  Download (Mbit/s)  Upload (Mbit/s)        Date      Time
# 0       26.992              91.80            14.31  2016-11-24  13:36:25
# 1       24.532              88.19            14.12  2016-11-24  13:36:55
# 2       20.225              59.86            14.11  2016-11-24  13:37:25
# 3       19.332              91.81            14.22  2016-11-24  13:37:57
# 4       22.494              92.05            14.08  2016-11-24  13:38:27
# ..         ...                ...              ...         ...       ...
# 668     20.952              88.67            14.35  2016-11-24  19:15:32
# 669     19.397              84.86            14.35  2016-11-24  19:16:04
# 670     20.117              84.99            14.33  2016-11-24  19:16:34
# 671     17.995              86.21             6.88  2016-11-24  19:17:04
# 672     22.175              85.69            14.23  2016-11-24  19:18:16
#
# [673 rows x 5 columns]
